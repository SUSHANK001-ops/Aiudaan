# %%
# import pandas as pd
# result = pd.Series(["japan","usa","nepal"])
# print(result)
# Out:
# 0    japan
# 1      usa
# 2    nepal
# dtype: str

# %%
# numseries = pd.Series([10,20,30,40])
# print(numseries)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %% [markdown]
# # day 9 of pandas
